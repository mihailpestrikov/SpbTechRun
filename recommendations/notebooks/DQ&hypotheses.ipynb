# %% [markdown]
# # Загрузка данных, импорт библиотек и настройка окружения

# %%
from google.colab import drive
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import re
from collections import Counter

drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
categories_path = '/content/drive/MyDrive/maxidom_contest/data/categories.csv'
offers_expanded_path = '/content/drive/MyDrive/maxidom_contest/data/offers_expanded.csv'
promos_path = '/content/drive/MyDrive/maxidom_contest/data/promos.csv'
offers_path = '/content/drive/MyDrive/maxidom_contest/data/offers.csv'

# %%
offers_expanded = pd.read_csv(offers_path)
categories = pd.read_csv(categories_path)
promos = pd.read_csv(promos_path)
offers = pd.read_csv(offers_path)

# %% [markdown]
# # Data Quality

# %% [markdown]
# ### Структура данных - offers

# %%
print("\nТипы данных:")
print(offers.dtypes)
print("\nИнформация:")
offers.info()
# Out:
# Типы данных:
# offer_id                 int64
# available                 bool
# url                     object
# price                  float64
# currency                object
# category_id              int64
# picture                 object
# sales_notes             object
# delivery                  bool
# local_delivery_cost    float64
# name                    object
# vendor                  object
# country_of_origin       object
# description             object
# market_description      object
# weight                 float64
# params                  object
# dtype: object
#
# Информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64490 entries, 0 to 64489
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   offer_id             64490 non-null  int64
#  1   available            64490 non-null  bool
#  2   url                  64490 non-null  object
#  3   price                64490 non-null  float64
#  4   currency             64490 non-null  object
#  5   category_id          64490 non-null  int64
#  6   picture              64490 non-null  object
#  7   sales_notes          64490 non-null  object
#  8   delivery             64490 non-null  bool
#  9   local_delivery_cost  64490 non-null  float64
#  10  name                 64490 non-null  object
#  11  vendor               64490 non-null  object
#  12  country_of_origin    64490 non-null  object
#  13  description          64490 non-null  object
#  14  market_description   63663 non-null  object
#  15  weight               64490 non-null  float64
#  16  params               64490 non-null  object
# dtypes: bool(2), float64(3), int64(2), object(10)
# memory usage: 7.5+ MB

# %% [markdown]
# ### Структура данных - categories

# %%
print("\nТипы данных:")
print(categories.dtypes)
print("\nИнформация:")
categories.info()
# Out:
# Типы данных:
# category_id      int64
# parent_id      float64
# name            object
# dtype: object
#
# Информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3231 entries, 0 to 3230
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  3231 non-null   int64
#  1   parent_id    3204 non-null   float64
#  2   name         3231 non-null   object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 75.9+ KB

# %% [markdown]
# ### Структура данных - promos

# %%
print("\nТипы данных:")
print(promos.dtypes)
print("\nИнформация:")
promos.info()
# Out:
# Типы данных:
# promo_id            int64
# promo_type         object
# start_date         object
# end_date           object
# description        object
# url                object
# offer_id            int64
# discount_price    float64
# currency           object
# dtype: object
#
# Информация:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64437 entries, 0 to 64436
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   promo_id        64437 non-null  int64
#  1   promo_type      64437 non-null  object
#  2   start_date      64437 non-null  object
#  3   end_date        64437 non-null  object
#  4   description     64437 non-null  object
#  5   url             64437 non-null  object
#  6   offer_id        64437 non-null  int64
#  7   discount_price  64437 non-null  float64
#  8   currency        64437 non-null  object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 4.4+ MB

# %% [markdown]
# ### DQ анализ

# %%
def data_quality_report(df, df_name):

    print(f"Размер датасета: {df.shape[0]:,} строк, {df.shape[1]} колонок")
    print(f"Использование памяти: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB")

    # ПРОПУЩЕННЫЕ
    print("\n" + "─" * 80)
    print("  ПРОПУЩЕННЫЕ ЗНАЧЕНИЯ")
    print("─" * 80)

    missing = df.isnull().sum()
    missing_pct = (missing / len(df)) * 100

    missing_df = (
        pd.DataFrame({
            "Колонка": df.columns,
            "Пропуски": missing.values,
            "Процент": missing_pct.values
        })
        .sort_values("Пропуски", ascending=False)
    )

    if missing_df["Пропуски"].sum() > 0:
        print(missing_df[missing_df["Пропуски"] > 0].to_string(index=False))
    else:
        print("Пропущенных значений не обнаружено")

    # ДУБЛИКАТЫ
    print("\n" + "─" * 80)
    print("  ДУБЛИКАТЫ")
    print("─" * 80)

    duplicates = df.duplicated().sum()
    duplicates_pct = (duplicates / len(df)) * 100

    print(f"Всего дубликатов: {duplicates:,} ({duplicates_pct:.2f}%)")

    if duplicates > 0:
        print("\nПримеры дубликатов:")
        print(df[df.duplicated(keep=False)].head(10))

    # УНИКАЛЬНЫЕ
    print("\n" + "─" * 80)
    print("  УНИКАЛЬНЫЕ ЗНАЧЕНИЯ")
    print("─" * 80)

    uniqueness = []
    for col in df.columns:
        unique_count = df[col].nunique()
        unique_pct = (unique_count / len(df)) * 100

        uniqueness.append({
            "Колонка": col,
            "Уникальных": unique_count,
            "Процент": f"{unique_pct:.2f}%",
            "Тип": str(df[col].dtype)
        })

    uniqueness_df = pd.DataFrame(uniqueness)
    print(uniqueness_df.to_string(index=False))

    # ЧИСЛОВЫЕ КОЛОНКИ
    numeric_cols = df.select_dtypes(include=[np.number]).columns

    if len(numeric_cols) > 0:
        print("\n" + "─" * 80)
        print("  СТАТИСТИКА ЧИСЛОВЫХ КОЛОНОК")
        print("─" * 80)

        print(df[numeric_cols].describe().T)

        print("\nПроверка на выбросы (IQR):")

        for col in numeric_cols:
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1

            outliers = df[
                (df[col] < Q1 - 1.5 * IQR) |
                (df[col] > Q3 + 1.5 * IQR)
            ][col]

            if len(outliers) > 0:
                print(
                    f"  {col}: {len(outliers)} выбросов "
                    f"({len(outliers) / len(df) * 100:.2f}%)"
                )

     # ТЕКСТОВЫЕ КОЛОНКИ

    text_cols = df.select_dtypes(include=["object"]).columns
    skip_cols = ["url", "picture", "params"]
    meaningful_text_cols = [col for col in text_cols if col not in skip_cols]

    if len(meaningful_text_cols) > 0:

        print("\n" + "─" * 80)
        print("  СТАТИСТИКА ТЕКСТОВЫХ КОЛОНОК")
        print("─" * 80)

        for col in meaningful_text_cols:
            print(f"\n{col}:")
            print(f"  Уникальных значений: {df[col].nunique()}")

            unique_count = df[col].nunique()

            if unique_count <= 5:
                print("  Распределение значений:")
                print(df[col].value_counts())

            elif unique_count <= 20:
                print("  Топ-10 значений:")
                print(df[col].value_counts().head(10))

    return missing_df

# %%
quality_offers = data_quality_report(offers, "OFFERS")
# Out:
# Размер датасета: 64,490 строк, 17 колонок
# Использование памяти: 147.94 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#   ПРОПУЩЕННЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
#            Колонка  Пропуски  Процент
# market_description       827 1.282369
#
# ────────────────────────────────────────────────────────────────────────────────
#   ДУБЛИКАТЫ
# ────────────────────────────────────────────────────────────────────────────────
# Всего дубликатов: 0 (0.00%)
#
# ────────────────────────────────────────────────────────────────────────────────
#   УНИКАЛЬНЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
#             Колонка  Уникальных Процент     Тип
#            offer_id       64490 100.00%   int64
#           available           1   0.00%    bool
#                 url       64490 100.00%  object
#               price        6520  10.11% float64
#            currency           1   0.00%  object
#         category_id        2273   3.52%   int64
#             picture       64490 100.00%  object
#         sales_notes           2   0.00%  object
#            delivery           1   0.00%    bool
# local_delivery_cost           1   0.00% float64
#                name       64080  99.36%  object
#              vendor        1555   2.41%  object
#   country_of_origin          62   0.10%  object
#         description       59653  92.50%  object
#  market_description       35783  55.49%  object
#              weight        4156   6.44% float64
#              params       64490 100.00%  object
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ЧИСЛОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#                        count          mean           std        min  \
# offer_id             64490.0  1.109676e+07  3.434715e+06  3235767.0
# price                64490.0  2.617924e+03  6.778512e+03        4.0
# category_id          64490.0  2.767465e+04  2.923735e+03    22925.0
# local_delivery_cost  64490.0  3.500000e+02  0.000000e+00      350.0
# weight               64490.0  3.531252e+00  1.155028e+01        0.0
#
#                             25%          50%          75%         max
# offer_id             9423040.75  12030253.50  13798296.25  15272333.0
# price                    235.00       599.00      2090.00    209990.0
# category_id            25052.00     27647.00     29750.75     34859.0
# local_delivery_cost      350.00       350.00       350.00       350.0
# weight                     0.10         0.38         1.57       325.0
#
# Проверка на выбросы (IQR):
#   price: 8033 выбросов (12.46%)
#   weight: 9340 выбросов (14.48%)
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ТЕКСТОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#
# currency:
#   Уникальных значений: 1
#   Распределение значений:
# currency
# RUB    64490
# Name: count, dtype: int64
#
# sales_notes:
#   Уникальных значений: 2
#   Распределение значений:
# sales_notes
# Более 40 000 товаров. Быстрая доставка по РФ                   61563
# Более 40 000 товаров. Быстрая доставка по РФ. Только онлайн     2927
# Name: count, dtype: int64
#
# name:
#   Уникальных значений: 64080
#
# vendor:
#   Уникальных значений: 1555
#
# country_of_origin:
#   Уникальных значений: 62
#
# description:
#   Уникальных значений: 59653
#
# market_description:
#   Уникальных значений: 35783

# %%
quality_categories = data_quality_report(categories, "CATEGORIES")
# Out:
# Размер датасета: 3,231 строк, 3 колонок
# Использование памяти: 0.39 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#   ПРОПУЩЕННЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
#   Колонка  Пропуски  Процент
# parent_id        27 0.835655
#
# ────────────────────────────────────────────────────────────────────────────────
#   ДУБЛИКАТЫ
# ────────────────────────────────────────────────────────────────────────────────
# Всего дубликатов: 0 (0.00%)
#
# ────────────────────────────────────────────────────────────────────────────────
#   УНИКАЛЬНЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
#     Колонка  Уникальных Процент     Тип
# category_id        3231 100.00%   int64
#   parent_id         438  13.56% float64
#        name        3209  99.32%  object
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ЧИСЛОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#               count          mean          std      min      25%      50%  \
# category_id  3231.0  28928.023522  3337.278161  22906.0  25750.5  28941.0
# parent_id    3204.0  27241.927903  3629.126258  22906.0  24566.0  25496.0
#
#                  75%      max
# category_id  31453.5  34859.0
# parent_id    29713.0  34836.0
#
# Проверка на выбросы (IQR):
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ТЕКСТОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#
# name:
#   Уникальных значений: 3209

# %%
quality_promos = data_quality_report(promos, "PROMOS")
# Out:
# Размер датасета: 64,437 строк, 9 колонок
# Использование памяти: 26.24 MB
#
# ────────────────────────────────────────────────────────────────────────────────
#   ПРОПУЩЕННЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
# Пропущенных значений не обнаружено
#
# ────────────────────────────────────────────────────────────────────────────────
#   ДУБЛИКАТЫ
# ────────────────────────────────────────────────────────────────────────────────
# Всего дубликатов: 0 (0.00%)
#
# ────────────────────────────────────────────────────────────────────────────────
#   УНИКАЛЬНЫЕ ЗНАЧЕНИЯ
# ────────────────────────────────────────────────────────────────────────────────
#        Колонка  Уникальных Процент     Тип
#       promo_id           1   0.00%   int64
#     promo_type           1   0.00%  object
#     start_date           1   0.00%  object
#       end_date           1   0.00%  object
#    description           1   0.00%  object
#            url           1   0.00%  object
#       offer_id       64437 100.00%   int64
# discount_price        6508  10.10% float64
#       currency           1   0.00%  object
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ЧИСЛОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#                   count          mean           std         min         25%  \
# promo_id        64437.0  1.000000e+00  0.000000e+00        1.00        1.00
# offer_id        64437.0  1.109829e+07  3.434588e+06  3235767.00  9423139.00
# discount_price  64437.0  2.582070e+03  6.688101e+03        3.96      232.65
#
#                         50%          75%         max
# promo_id               1.00         1.00         1.0
# offer_id        12030333.00  13798324.00  15272333.0
# discount_price       593.01      2064.15    207890.1
#
# Проверка на выбросы (IQR):
#   discount_price: 8012 выбросов (12.43%)
#
# ────────────────────────────────────────────────────────────────────────────────
#   СТАТИСТИКА ТЕКСТОВЫХ КОЛОНОК
# ────────────────────────────────────────────────────────────────────────────────
#
# promo_type:
#   Уникальных значений: 1
#   Распределение значений:
# promo_type
# bonus card    64437
# Name: count, dtype: int64
#
# start_date:
#   Уникальных значений: 1
#   Распределение значений:
# start_date
# 2020-02-01    64437
# Name: count, dtype: int64
#
# end_date:
#   Уникальных значений: 1
#   Распределение значений:
# end_date
# 2024-04-15    64437
# Name: count, dtype: int64
#
# description:
#   Уникальных значений: 1
#   Распределение значений:
# description
# Скидка по карте    64437
# Name: count, dtype: int64
#
# currency:
#   Уникальных значений: 1
#   Распределение значений:
# currency
# RUB    64437
# Name: count, dtype: int64

# %% [markdown]
# ### Анализ связей между таблицами

# %%
if 'category_id' in offers.columns and 'category_id' in categories.columns:
    print("\nOFFERS и CATEGORIES")
    print("─" * 80)

    offers_with_cat = offers.merge(categories, on='category_id', how='left', indicator=True)

    print(f"Всего товаров в offers: {len(offers):,}")
    print(f"Товаров с найденными категориями: {(offers_with_cat['_merge'] == 'both').sum():,}")
    print(f"Товаров без категорий: {(offers_with_cat['_merge'] == 'left_only').sum():,}")

    orphan_categories = set(offers['category_id'].dropna()) - set(categories['category_id'].dropna())
    print(f"Несуществующих category_id в offers: {len(orphan_categories)}")
    if len(orphan_categories) > 0 and len(orphan_categories) < 20:
        print(f"Примеры: {list(orphan_categories)[:10]}")

if 'offer_id' in offers.columns and 'offer_id' in promos.columns:
    print("\nOFFERS и PROMOS")
    print("─" * 80)

    offers_in_promos = set(promos['offer_id'].dropna())
    offers_in_offers = set(offers['offer_id'].dropna())

    print(f"Всего товаров в offers: {len(offers):,}")
    print(f"Товаров с промо: {len(offers_in_promos):,}")
    print(f"Процент товаров с промо: {len(offers_in_promos) / len(offers) * 100:.2f}%")

    missing_offers = offers_in_promos - offers_in_offers
    print(f"Товаров из promos, которых нет в offers: {len(missing_offers)}")
    if len(missing_offers) > 0 and len(missing_offers) < 20:
        print(f"Примеры: {list(missing_offers)[:10]}")
# Out:
# OFFERS и CATEGORIES
# ────────────────────────────────────────────────────────────────────────────────
# Всего товаров в offers: 64,490
# Товаров с найденными категориями: 64,490
# Товаров без категорий: 0
# Несуществующих category_id в offers: 0
#
# OFFERS и PROMOS
# ────────────────────────────────────────────────────────────────────────────────
# Всего товаров в offers: 64,490
# Товаров с промо: 64,437
# Процент товаров с промо: 99.92%
# Товаров из promos, которых нет в offers: 0

# %% [markdown]
# ### Бизнес-ориентированные проверки данных

# %%
if 'available' in offers.columns:
    print("\nДОСТУПНОСТЬ ТОВАРОВ")
    print("─" * 80)
    availability = offers['available'].value_counts()
    print(availability)
    total = len(offers)
    for val, count in availability.items():
        print(f"{val}: {count:,} ({count/total*100:.2f}%)")

if 'price' in offers.columns:
    print("\nАНАЛИЗ ЦЕН")
    print("─" * 80)
    prices = offers['price'].dropna()
    print(f"Товаров с ценой: {len(prices):,}")
    print(f"Товаров без цены: {offers['price'].isna().sum():,}")
    print(f"Минимальная цена: {prices.min():.2f}")
    print(f"Максимальная цена: {prices.max():.2f}")
    print(f"Средняя цена: {prices.mean():.2f}")
    print(f"Медианная цена: {prices.median():.2f}")

    zero_prices = (offers['price'] == 0).sum()
    if zero_prices > 0:
        print(f"\nТоваров с нулевой ценой: {zero_prices:,}")

if 'currency' in offers.columns:
    print("\nВАЛЮТЫ")
    print("─" * 80)
    print(offers['currency'].value_counts())

if 'vendor' in offers.columns:
    print("\nПРОИЗВОДИТЕЛИ (Топ-20)")
    print("─" * 80)
    print(offers['vendor'].value_counts().head(20))

if 'parent_id' in categories.columns:
    print("\nИЕРАРХИЯ КАТЕГОРИЙ")
    print("─" * 80)
    root_categories = categories[categories['parent_id'].isna()]
    print(f"Корневых категорий: {len(root_categories)}")
    print(f"Категорий с родителем: {len(categories) - len(root_categories)}")

    max_depth = 0
    for cat_id in root_categories['category_id'].values:
        depth = 0
        current_level = [cat_id]
        while current_level:
            depth += 1
            next_level = []
            for c_id in current_level:
                children = categories[categories['parent_id'] == c_id]['category_id'].values
                next_level.extend(children)
            current_level = next_level
        max_depth = max(max_depth, depth)

    print(f"Максимальная глубина дерева категорий: {max_depth}")

if 'promo_type' in promos.columns:
    print("\nТИПЫ ПРОМО-АКЦИЙ")
    print("─" * 80)
    print(promos['promo_type'].value_counts())

if 'discount_price' in promos.columns and 'offer_id' in promos.columns:
    print("\nСТАТИСТИКА СКИДОК")
    print("─" * 80)

    promos_with_offers = promos.merge(
        offers[['offer_id', 'price']],
        on='offer_id',
        how='left'
    )

    promos_with_offers['discount_amount'] = promos_with_offers['price'] - promos_with_offers['discount_price']
    promos_with_offers['discount_percent'] = (promos_with_offers['discount_amount'] / promos_with_offers['price']) * 100

    valid_discounts = promos_with_offers['discount_percent'].dropna()
    if len(valid_discounts) > 0:
        print(f"Средняя скидка: {valid_discounts.mean():.2f}%")
        print(f"Медианная скидка: {valid_discounts.median():.2f}%")
        print(f"Минимальная скидка: {valid_discounts.min():.2f}%")
        print(f"Максимальная скидка: {valid_discounts.max():.2f}%")
# Out:
# ДОСТУПНОСТЬ ТОВАРОВ
# ────────────────────────────────────────────────────────────────────────────────
# available
# True    64490
# Name: count, dtype: int64
# True: 64,490 (100.00%)
#
# АНАЛИЗ ЦЕН
# ────────────────────────────────────────────────────────────────────────────────
# Товаров с ценой: 64,490
# Товаров без цены: 0
# Минимальная цена: 4.00
# Максимальная цена: 209990.00
# Средняя цена: 2617.92
# Медианная цена: 599.00
#
# ВАЛЮТЫ
# ────────────────────────────────────────────────────────────────────────────────
# currency
# RUB    64490
# Name: count, dtype: int64
#
# ПРОИЗВОДИТЕЛИ (Топ-20)
# ────────────────────────────────────────────────────────────────────────────────
# vendor
# Нет марки      11385
# MAXIJOY         1869
# ЕВРОПАРТНЕР     1268
# ЭРА              927
# TODELIA          820
# UGO LOKS         681
# УЮТ              670
# NAVIGATOR        666
# AMBRELLA         609
# KOOPMAN          552
# РЫЖИЙ КОТ        456
# VITARTA          427
# SALAG            408
# ПОИСК            393
# MALLONY          390
# СТРОЙБАТ         366
# VENMEB           332
# KENDO            315
# GAH ALBERTS      315
# Не указана       313
# Name: count, dtype: int64
#
# ИЕРАРХИЯ КАТЕГОРИЙ
# ────────────────────────────────────────────────────────────────────────────────
# Корневых категорий: 27
# Категорий с родителем: 3204
# Максимальная глубина дерева категорий: 4
#
# ТИПЫ ПРОМО-АКЦИЙ
# ────────────────────────────────────────────────────────────────────────────────
# promo_type
# bonus card    64437
# Name: count, dtype: int64
#
# СТАТИСТИКА СКИДОК
# ────────────────────────────────────────────────────────────────────────────────
# Средняя скидка: 1.00%
# Медианная скидка: 1.00%
# Минимальная скидка: 1.00%
# Максимальная скидка: 1.00%

# %% [markdown]
# ## Гипотеза 1: Категориальная близость
#
# **Описание:** Товары из одной или смежных категорий чаще покупаются вместе.
#
# **Обоснование:**
# - Данные показывают иерархическую структуру категорий с глубиной до 4 уровней
# - 2273 уникальных категорий обеспечивают хорошую гранулярность
# - Пользователи часто ищут дополнительные товары в той же категории
#
# **Метод проверки:**
# - Учитывать иерархию категорий (родительские и дочерние)
# - Использовать one-hot encoding или embeddings для категорий

# %% [markdown]
# ## Гипотеза 2: Текстовое сходство товаров
#
# **Описание:** Товары с похожими названиями, описаниями и характеристиками являются хорошими кандидатами для рекомендаций.
#
# **Обоснование:**
# - 64080 уникальных названий товаров (99.36% уникальности)
# - 59653 уникальных описаний (92.50%)
# - Поле params содержит структурированные характеристики для всех товаров
# - Текстовая информация очень богата и детализирована
#
# **Метод проверки:**
# - Использовать TF-IDF или word embeddings для name, description, market_description
# - Парсить и векторизовать поле params
# - Вычислять косинусное сходство между товарами
# - Создать гибридную модель text + category features

# %% [markdown]
# ## Гипотеза 3: Ценовой сегмент и доступность
#
# **Описание:** Пользователи склонны выбирать товары в похожем ценовом диапазоне.
#
# **Обоснование:**
# - Широкий диапазон цен: от 4 до 209,990 руб
# - Медианная цена (599 руб) сильно отличается от средней (2,618 руб)
# - 12.46% выбросов по ценам указывают на разные ценовые сегменты
# - 99.92% товаров имеют промо-акции
#
# **Метод проверки:**
# - Сегментировать товары по ценовым диапазонам (бюджетный, средний, премиум)
# - Рекомендовать товары в том же ценовом сегменте ±20%
# - Учитывать наличие скидок (discount_price vs price)
# - Повышать приоритет товаров с активными промо-акциями

# %% [markdown]
# ## Гипотеза 4: Брендовая лояльность
#
# **Описание:** Пользователи, покупающие товары определенного производителя, с большей вероятностью купят другие товары этого же бренда.
#
# **Обоснование:**
# - 1555 уникальных производителей
# - "Нет марки" доминирует с 11,385 товарами (17.7%)
# - Топ-20 брендов покрывают значительную часть каталога
# - Бренды как MAXIJOY, ЕВРОПАРТНЕР имеют широкий ассортимент
#
# **Метод проверки:**
# - Группировать товары по полю vendor
# - Рекомендовать товары того же производителя

# %% [markdown]
# ## Гипотеза 5: Комплементарность по весу и характеристикам
#
# **Описание:** Товары с разным весом и характеристиками могут быть комплементарными (например, основной товар + аксессуары).
#
# **Обоснование:**
# - Вес варируется от 0 до 325 кг (14.48% выбросов)
# - 4156 уникальных значений веса
# - Поле params содержит дополнительные характеристики
# - Строительный магазин предполагает покупку связанных товаров
#
# **Метод проверки:**
# - Анализировать товары с сильно отличающимся весом из одной категории
# - Искать паттерны "тяжелый товар + легкие аксессуары"
# - Парсить params для выявления комплементарных характеристик
# - Создать правила ассоциаций на основе физических свойств

# %% [markdown]
# # Приоритет гипотез

# %% [markdown]
# **1. Гипотеза 2 (Текстовое сходство)** - ВЫСОКИЙ ПРИОРИТЕТ
#    - Очень высокая уникальность названий (99.36%) и описаний (92.50%)
#    - Поле params содержит детальные характеристики
#
# **2. Гипотеза 1 (Категориальная близость)** - ВЫСОКИЙ ПРИОРИТЕТ
#    - Хорошо структурированная иерархия категорий (4 уровня)
#    - 2273 категорий обеспечивают детализацию
#    - Комбинируется хорошо с другими подходами
#
# **3. Гипотеза 4 (Брендовая лояльность)** - СРЕДНИЙ ПРИОРИТЕТ
#    - 1555 производителей, топ-20 покрывают значительную долю
#    - Проблема: 17.7% товаров "Нет марки"
#    - Подходит как дополнительный сигнал
#
# **4. Гипотеза 3 (Ценовой сегмент)** - СРЕДНИЙ ПРИОРИТЕТ
#    - Широкий диапазон цен предполагает разные сегменты
#    - 99.92% товаров с промо можно использовать для буста
#    - Хорошо работает для фильтрации, но не для основной рекомендации
#
# **5. Гипотеза 5 (Комплементарность по весу)** - НИЗКИЙ ПРИОРИТЕТ
#    - Интересная идея, но требует дополнительных данных о покупках
#    - Без исторических данных сложно определить комплементарность
#    - Может быть полезна для кросс-продаж
